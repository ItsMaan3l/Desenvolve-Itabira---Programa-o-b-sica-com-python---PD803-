# %%
Q1

# %%
hora_salario = 20
horasp_semana = 40
salario_bruto = hora_salario * horasp_semana
print (salario_bruto)
# Out:
# 800

# %%
Q2

# %%
desconto = salario_bruto * 0.10
print (desconto)
# Out:
# 80.0

# %%
Q3

# %%
reais = 100
yuan = reais / 0.69

print("Valor em yuan:", yuan)
# Out:
# Valor em yuan: 144.92753623188406

# %%
Q4

# %%
distancia_metros = 42.195 * 1000
tempo_segundos = 3 * 3600

velocidade = distancia_metros / tempo_segundos

print("Velocidade média necessária:", velocidade, "m/s")
# Out:
# Velocidade média necessária: 3.9069444444444446 m/s
